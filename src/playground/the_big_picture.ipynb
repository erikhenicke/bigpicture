# %% [markdown]
# # The Big Picture - Context Retrieval
#
# Notebook to combine high-resolution FMoW satellite image with broader but lower-resolution Landsat image from Google Earth Engine by patching the high-res image into the low-res image.

# %%
"""
Requirements:
- earthengine-api
- rasterio
- numpy
- boto3 (for AWS S3 access)
- Pillow
- pyproj
"""

import ee
import geemap
import boto3
from botocore import UNSIGNED
from botocore.config import Config
import tempfile
import os
import json
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
prefix = f'Hosted-Datasets/fmow/fmow-rgb/'
s3 = boto3.client(
    's3',
    region_name='us-east-1',
    config=Config(signature_version=UNSIGNED)
)
bucket_name = 'spacenet-dataset'
response = s3.list_objects_v2(Bucket=bucket_name, Prefix=prefix, MaxKeys=100)
response
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# {'ResponseMetadata': {'RequestId': 'KAQH0D3M83WXYBYE',
#   'HostId': 'b0g+JnkPRGUlC2bwE4ez+VJdSxG26DNIVNz5+E3GOytqwqIbY5Ek09wQQnbubQJ7kQCt3cyxM+I=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'b0g+JnkPRGUlC2bwE4ez+VJdSxG26DNIVNz5+E3GOytqwqIbY5Ek09wQQnbubQJ7kQCt3cyxM+I=',
#    'x-amz-request-id': 'KAQH0D3M83WXYBYE',
#    'date': 'Thu, 13 Nov 2025 12:55:44 GMT',
#    'x-amz-bucket-region': 'us-east-1',
#    'content-type': 'application/xml',
#    'transfer-encoding': 'chunked',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'IsTruncated': True,
#  'Contents': [{'Key': 'Hosted-Datasets/fmow/fmow-rgb/CHANGELOG.md',
#    'LastModified': datetime.datetime(2019, 8, 15, 22, 57, 17, tzinfo=tzutc()),
#    'ETag': '"6f566b599066484cef89a275f5d46b7a"',
#    'Size': 1707,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'Hosted-Datasets/fmow/fmow-rgb/IARPA-fMoW.pdf',
#    'LastModified': datetime.datetime(2019, 8, 15, 22, 57, 17, tzinfo=tzutc()),
#    'ETag': '"738b61c620dfac03e9cd24b190244858"',
#    'Size': 692697,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'Hosted-Datasets/fmow/fmow-rgb/LICENSE',
#    'LastModified': datetime.datetime(2019, 8, 15, 22, 57, 17, tzinfo=tzutc()),
#    'ETag': '"d355d86f382c56ec475c641c53c8cac2"',
#    'Size': 15096,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'Hosted-Datasets/fmow/fmow-rgb/README.md',
#    'LastModified': datetime.datetime(2019, 8, 15, 22, 57, 17, tzinfo=tzutc()),
#    'ETag': '"2afa54cb40275201198e94068e5835af"',
#    'Size': 2461,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'Hosted-Datasets/fmow/fmow-rgb/fMoW-rgb_seqandgt_v1.2.1.torrent',
#    'LastModified': datetime.datetime(2019, 8, 15, 22, 57, 17, tzinfo=tzutc()),
#    'ETag': '"2bb7f87ce41f699481d2fab535fb23b1"',
#    'Size': 27954,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'Hosted-Datasets/fmow/fmow-rgb/fMoW-rgb_test_v1.0.0.torrent',
#    'LastModified': datetime.datetime(2019, 8, 15, 22, 57, 17, tzinfo=tzutc()),
#    'ETag': '"35270b71aec8174743f94c72ac11070f"',
#    'Size': 29241,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'Hosted-Datasets/fmow/fmow-rgb/fMoW-rgb_trainval_v1.0.0.torrent',
#    'LastModified': datetime.datetime(2019, 8, 15, 22, 57, 17, tzinfo=tzutc()),
#    'ETag': '"6692a3e3ed9c12a0a3528750c425b035"',
#    'Size': 55082,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'Hosted-Datasets/fmow/fmow-rgb/fMoW-rgb_val_sample_v1.1.0.torrent',
#    'LastModified': datetime.datetime(2019, 8, 15, 22, 57, 17, tzinfo=tzutc()),
#    'ETag': '"f23f09634d332a46d5fb797d4591db03"',
#    'Size': 2871653,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'Hosted-Datasets/fmow/fmow-rgb/groundtruth.tar.bz2',
#    'LastModified': datetime.datetime(2019, 8, 15, 22, 57, 17, tzinfo=tzutc()),
#    'ETag': '"d27aa6c9c2fd797b13eec523dbc1e133-30"',
#    'Size': 245218563,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'Hosted-Datasets/fmow/fmow-rgb/manifest.json.bz2',
#    'LastModified': datetime.datetime(2019, 8, 15, 22, 57, 17, tzinfo=tzutc()),
#    'ETag': '"51507b217a37ea58d7380ff958938b50"',
#    'Size': 4630040,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'Hosted-Datasets/fmow/fmow-rgb/seq/0000000/0000000_0_msrgb.jpg',
#    'LastModified': datetime.datetime(2019, 8, 15, 22, 57, 17, tzinfo=tzutc()),
#    'ETag': '"a16f5aaf65a820e90f3a590ce8329dfe"',
#    'Size': 13140,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'Hosted-Datasets/fmow/fmow-rgb/seq/0000000/0000000_0_msrgb.json',
#    'LastModified': datetime.datetime(2019, 8, 15, 22, 57, 17, tzinfo=tzutc()),
#    'ETag': '"6e70100994ed554edd89d84ba8b61c13"',
#    'Size': 1751,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'Hosted-Datasets/fmow/fmow-rgb/seq/0000000/0000000_0_rgb.jpg',
#    'LastModified': datetime.datetime(2019, 8, 15, 22, 57, 17, tzinfo=tzutc()),
#    'ETag': '"796f6ea425876cc322ba569bc12d67e9"',
#    'Size': 108458,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'Hosted-Datasets/fmow/fmow-rgb/seq/0000000/0000000_0_rgb.json',
#    'LastModified': datetime.datetime(2019, 8, 15, 22, 57, 17, tzinfo=tzutc()),
#    'ETag': '"b14095ec75ee0f227c7b23fc21ebd89a"',
#    'Size': 1756,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'Hosted-Datasets/fmow/fmow-rgb/seq/0000000/0000000_2_msrgb.jpg',
#    'LastModified': datetime.datetime(2019, 8, 15, 22, 57, 17, tzinfo=tzutc()),
#    'ETag': '"2e5d289f1d519f75bbdd5d50b8733432"',
#    'Size': 11697,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'Hosted-Datasets/fmow/fmow-rgb/seq/0000000/0000000_2_msrgb.json',
#    'LastModified': datetime.datetime(2019, 8, 15, 22, 57, 17, tzinfo=tzutc()),
#    'ETag': '"e6aef5960aabe546ca25882fb819b5b9"',
#    'Size': 1750,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'Hosted-Datasets/fmow/fmow-rgb/seq/0000000/0000000_2_rgb.jpg',
#    'LastModified': datetime.datetime(2019, 8, 15, 22, 57, 17, tzinfo=tzutc()),
#    'ETag': '"1572c92387599553abde368a838410f9"',
#    'Size': 87006,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'Hosted-Datasets/fmow/fmow-rgb/seq/0000000/0000000

#    'StorageClass': 'STANDARD'},
#   {'Key': 'Hosted-Datasets/fmow/fmow-rgb/seq/0000004/0000004_0_rgb.json',
#    'LastModified': datetime.datetime(2019, 8, 15, 22, 57, 20, tzinfo=tzutc()),
#    'ETag': '"cc426f710da880a05514870718613805"',
#    'Size': 1748,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'Hosted-Datasets/fmow/fmow-rgb/seq/0000005/0000005_0_msrgb.jpg',
#    'LastModified': datetime.datetime(2019, 8, 15, 22, 57, 20, tzinfo=tzutc()),
#    'ETag': '"b52fd0c8b4bcf59e502215b1f71dfc37"',
#    'Size': 5985,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'Hosted-Datasets/fmow/fmow-rgb/seq/0000005/0000005_0_msrgb.json',
#    'LastModified': datetime.datetime(2019, 8, 15, 22, 57, 20, tzinfo=tzutc()),
#    'ETag': '"b729921e275c0f1cd0930a06b3bd0323"',
#    'Size': 1748,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'Hosted-Datasets/fmow/fmow-rgb/seq/0000005/0000005_0_rgb.jpg',
#    'LastModified': datetime.datetime(2019, 8, 15, 22, 57, 20, tzinfo=tzutc()),
#    'ETag': '"6a8eba5c40e9882c67d47dd4465d210a"',
#    'Size': 51798,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'Hosted-Datasets/fmow/fmow-rgb/seq/0000005/0000005_0_rgb.json',
#    'LastModified': datetime.datetime(2019, 8, 15, 22, 57, 20, tzinfo=tzutc()),
#    'ETag': '"bbf4cb43c2700e6e88b83bd030c984f8"',
#    'Size': 1744,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'Hosted-Datasets/fmow/fmow-rgb/seq/0000005/0000005_1_msrgb.jpg',
#    'LastModified': datetime.datetime(2019, 8, 15, 22, 57, 20, tzinfo=tzutc()),
#    'ETag': '"a9b14c9b9b23d3e9ab91c5ec47719d07"',
#    'Size': 5671,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'Hosted-Datasets/fmow/fmow-rgb/seq/0000005/0000005_1_msrgb.json',
#    'LastModified': datetime.datetime(2019, 8, 15, 22, 57, 20, tzinfo=tzutc()),
#    'ETag': '"c6bf089a230070a5208dbff3d7f91895"',
#    'Size': 1744,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'Hosted-Datasets/fmow/fmow-rgb/seq/0000005/0000005_1_rgb.jpg',
#    'LastModified': datetime.datetime(2019, 8, 15, 22, 57, 26, tzinfo=tzutc()),
#    'ETag': '"00b7d8fb6c7542e81c6a374711bf5fbb"',
#    'Size': 37160,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'Hosted-Datasets/fmow/fmow-rgb/seq/0000005/0000005_1_rgb.json',
#    'LastModified': datetime.datetime(2019, 8, 15, 22, 57, 21, tzinfo=tzutc()),
#    'ETag': '"b42d59beee8c380df7786a2a968e9369"',
#    'Size': 1740,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'Hosted-Datasets/fmow/fmow-rgb/seq/0000005/0000005_2_msrgb.jpg',
#    'LastModified': datetime.datetime(2019, 8, 15, 22, 57, 21, tzinfo=tzutc()),
#    'ETag': '"ddfe0e10a345176cbcc6f5e41b090ce2"',
#    'Size': 16420,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'Hosted-Datasets/fmow/fmow-rgb/seq/0000005/0000005_2_msrgb.json',
#    'LastModified': datetime.datetime(2019, 8, 15, 22, 57, 21, tzinfo=tzutc()),
#    'ETag': '"1fbe10c70dbfc106b9b5707987c39070"',
#    'Size': 1744,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'Hosted-Datasets/fmow/fmow-rgb/seq/0000005/0000005_2_rgb.jpg',
#    'LastModified': datetime.datetime(2019, 8, 15, 22, 57, 21, tzinfo=tzutc()),
#    'ETag': '"bbe4dc00672101e6cd8e061a2c6a6484"',
#    'Size': 144730,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'Hosted-Datasets/fmow/fmow-rgb/seq/0000005/0000005_2_rgb.json',
#    'LastModified': datetime.datetime(2019, 8, 15, 22, 57, 21, tzinfo=tzutc()),
#    'ETag': '"5a50212f4a81254e7ab38187574214d4"',
#    'Size': 1756,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'Hosted-Datasets/fmow/fmow-rgb/seq/0000006/0000006_0_msrgb.jpg',
#    'LastModified': datetime.datetime(2019, 8, 15, 22, 57, 21, tzinfo=tzutc()),
#    'ETag': '"bc8e02bdaef51cf6386e4cf1361f5874"',
#    'Size': 30453,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'Hosted-Datasets/fmow/fmow-rgb/seq/0000006/0000006_0_msrgb.json',
#    'LastModified': datetime.datetime(2019, 8, 15, 22, 57, 21, tzinfo=tzutc()),
#    'ETag': '"1b5b22c86c1f8fe5e384675844afdd4e"',
#    'Size': 1949,
#    'StorageClass': 'STANDARD'}],
#  'Name': 'spacenet-dataset',
#  'Prefix': 'Hosted-Datasets/fmow/fmow-rgb/',
#  'MaxKeys': 100,
#  'EncodingType': 'url',
#  'KeyCount': 100,
#  'NextContinuationToken': '1VL3Ut7a0u8b+rzvPr8Mf3v2orbsp0bfz+/9Fm24FhNj8kBLUDoYuUYmZw6Tdi9FVyizp0eqS2DO48cD4BuLMVHk4Eh6awBGBR7WLGMiX9PlEqqWqs4SKmg=='}

# %%
def download_fmow_image(split, category, index=0):
    temp_dir = tempfile.mkdtemp()
    s3 = boto3.client(
        's3',
        region_name='us-east-1',
        config=Config(signature_version=UNSIGNED)
    )
    bucket_name = 'spacenet-dataset'
    prefix = f'Hosted-Datasets/fmow/fmow-rgb/{split}/{category}/'
    response = s3.list_objects_v2(Bucket=bucket_name, Prefix=prefix, MaxKeys=100)
    
    image_files = [obj['Key'] for obj in response['Contents'] 
        if obj['Key'].endswith(('.jpg', '.png', '.tif'))]
    image_key = image_files[min(index, len(image_files)-1)]
    image_path = os.path.join(temp_dir, f"fmow_image.jpg")

    print("Downloading image")
    s3.download_file(bucket_name, image_key, image_path)
    print(f"Downloaded successfully to {image_path}")

    base_path = os.path.splitext(image_key)[0]
    metadata_key = base_path + '.json'
    metadata_path = os.path.join(temp_dir, "fmow_metadata.json")

    metadata = {}
    s3.download_file(bucket_name, metadata_key, metadata_path)
    with open(metadata_path, 'r') as f:
        metadata = json.load(f)
    print(f"Metadata downloaded successfully")

    return metadata

metadata = download_fmow_image("train", "airport")
print(metadata)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Downloading image
# Downloaded successfully to /tmp/tmpmlp_e459/fmow_image.jpg
# Metadata downloaded successfully
# {'img_filename': 'airport_0_0_msrgb.jpg', 'bounding_boxes': [{'category': 'airport', 'ID': 144, 'visible': 'True', 'box': [174, 363, 1429, 661]}], 'gsd': 2.45140385628, 'img_width': 2050, 'img_height': 1578, 'mean_pixel_height': 2.1906917870723e-05, 'mean_pixel_width': 2.1910128878048e-05, 'utm': '36S', 'country_code': 'TUR', 'cloud_cover': 0, 'timestamp': '2002-02-07T08:43:59Z', 'scan_direction': 'Forward', 'approximate_wavelengths': [661, 545, 477], 'pan_resolution_dbl': 0.613170742989, 'pan_resolution_start_dbl': 0.613170742989, 'pan_resolution_end_dbl': 0.613170742989, 'pan_resolution_min_dbl': 0.613170742989, 'pan_resolution_max_dbl': 0.613170742989, 'multi_resolution_dbl': 2.45140385628, 'multi_resolution_start_dbl': 2.45140385628, 'multi_resolution_end_dbl': 2.45140385628, 'multi_resolution_min_dbl': 2.45140385628, 'multi_resolution_max_dbl': 2.45140385628, 'target_azimuth_dbl': 27.7898311615, 'target_azimuth_start_dbl': 27.733001709, 'target_azimuth_end_dbl': 27.840845108, 'target_azimuth_min_dbl': 27.733001709, 'target_azimuth_max_dbl': 27.840845108, 'sun_azimuth_dbl': 157.321589152, 'sun_azimuth_min_dbl': 157.311248779, 'sun_azimuth_max_dbl': 157.331832886, 'sun_elevation_dbl': 31.9062328339, 'sun_elevation_min_dbl': 31.8285388947, 'sun_elevation_max_dbl': 31.9840087891, 'off_nadir_angle_dbl': 3.90585215886, 'off_nadir_angle_start_dbl': 3.0332057476, 'off_nadir_angle_end_dbl': 4.77713823318, 'off_nadir_angle_min_dbl': 3.0332057476, 'off_nadir_angle_max_dbl': 4.77713823318}

# %%
'gsd' in metadata
metadata['gsd'] * metadata['img_height']
metadata['gsd'] * metadata['img_width']
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 5025.377905374

# %%
import tarfile
import io

s3 = boto3.client('s3',
                  region_name='us-east-1',
                  config=Config(signature_version=UNSIGNED))

bucket = 'spacenet-dataset'
key = 'Hosted-Datasets/fmow/fmow-rgb/groundtruth.tar.bz2'

print("Downloading groundtruth.tar.bz2 ...")
obj = s3.get_object(Bucket=bucket, Key=key)
stream = io.BytesIO(obj['Body'].read())
print("Download successful")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Downloading groundtruth.tar.bz2 ...
# Download successful

# %%
response = s3.head_object(Bucket=bucket, Key=key)
size = response['ContentLength']
print(size)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 245218563

# %%
with tarfile.open(fileobj=stream, mode='r:bz2') as tar:
    file = tar.extractfile('val/golf_course/golf_course_13/golf_course_13_3_rgb.json')
    print(json.load(file))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# {'img_filename': 'golf_course_13_3_rgb.jpg', 'bounding_boxes': [{'raw_category': 'Golf Course', 'category': 'golf_course', 'raw_location': 'POLYGON ((-69.9573118949585933 41.6878386408654507, -69.9529339536472747 41.6878386408654507, -69.9529339536472747 41.6848813904204221, -69.9573118949585933 41.6848813904204221, -69.9573118949585933 41.6878386408654507))', 'ID': -1, 'spatial_reference': 'GCS_WGS_1984', 'epsg': '4326', 'crowd_rank': 0.819959, 'box': [20, 77, 1464, 989]}, {'category': 'golf_course', 'ID': 16296, 'visible': 'True', 'box': [20, 77, 1464, 989]}], 'gsd': 0.333779722452, 'img_width': 1502, 'img_height': 1126, 'mean_pixel_height': 2.990142007106e-06, 'mean_pixel_width': 2.990397070572e-06, 'utm': '19T', 'country_code': 'USA', 'cloud_cover': 0, 'timestamp': '2016-06-27T15:55:29Z', 'scan_direction': 'Forward', 'approximate_wavelengths': [661, 545, 477], 'pan_resolution_dbl': 0.333779722452, 'pan_resolution_start_dbl': 0.332446455956, 'pan_resolution_end_dbl': 0.335012316704, 'pan_resolution_min_dbl': 0.332446455956, 'pan_resolution_max_dbl': 0.335012316704, 'multi_resolution_dbl': 1.33499765396, 'multi_resolution_start_dbl': 1.32966458797, 'multi_resolution_end_dbl': 1.33992815018, 'multi_resolution_min_dbl': 1.32966458797, 'multi_resolution_max_dbl': 1.33992815018, 'target_azimuth_dbl': 22.4310569763, 'target_azimuth_start_dbl': 18.0208969116, 'target_azimuth_end_dbl': 26.0540084839, 'target_azimuth_min_dbl': 18.0208969116, 'target_azimuth_max_dbl': 26.0540084839, 'sun_azimuth_dbl': 147.711349487, 'sun_azimuth_min_dbl': 147.104873657, 'sun_azimuth_max_dbl': 148.409118652, 'sun_elevation_dbl': 69.2828445435, 'sun_elevation_min_dbl': 68.7880096436, 'sun_elevation_max_dbl': 69.7003860474, 'off_nadir_angle_dbl': 16.4144096375, 'off_nadir_angle_start_dbl': 15.9539403915, 'off_nadir_angle_end_dbl': 16.8399772644, 'off_nadir_angle_min_dbl': 15.9539403915, 'off_nadir_angle_max_dbl': 16.8399772644, 'catalog_id': '104001001E9EF700', 'sensor_platform_name': 'WORLDVIEW03_VNIR', 'raw_location': 'POLYGON ((-69.957371702900005 41.684701981899998, -69.952880126500006 41.684701981899998, -69.952880126500006 41.6880688818, -69.957371702900005 41.6880688818, -69.957371702900005 41.684701981899998))', 'spatial_reference': 'GCS_WGS_1984', 'epsg': '4326', 'abs_cal_factors': [{'band': 'nir', 'value': 0.0166926}, {'band': 'red', 'value': 0.0143856}, {'band': 'green', 'value': 0.0133187}, {'band': 'blue', 'value': 0.0176201}, {'band': 'rededge', 'value': 0.00621996}, {'band': 'yellow', 'value': 0.006901951}, {'band': 'coastal', 'value': 0.0143287}, {'band': 'nir2', 'value': 0.0106378}]}
