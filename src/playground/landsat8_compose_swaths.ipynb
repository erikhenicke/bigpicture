# %% [markdown]
# # Composing Images for full Region Coverage
#
# **Problem:** Some geografical regions need multiple swaths (satellite rows) to cover a geographical region, such that `ee.ImageCollection.first` in combination with `ee.Image.clip` leads to invalid images.
#
# To overcome this problem, multiple images can be composed using `ee.ImageCollection.mosaic` or `ee.ImageCollection.median`.

# %% [markdown]
# # Setup
# This problem appears when trying to retrieve surrounding satellite images for the training sample `airport 18` of fMoW, an airport in Lybia.

# %%
import ee
import geemap

EE_PROJECT_NAME = 'seeing-the-big-picture'

try:
    ee.Authenticate()
    ee.Initialize(project=EE_PROJECT_NAME)
except Exception as e:
    print("Please authenticate Earth Engine: earthengine authenticate")
    raise

# Rectange surrounding the training sample 'airport 18' from fMoW
bbox = [14.583450674625576, 27.177539780430607,
        14.718289694449945, 27.29808510902606]

center_coords = [27.237, 14.650]

region = ee.Geometry.Rectangle(bbox)

col = (ee.ImageCollection('LANDSAT/LC08/C02/T1_L2')
       .filterBounds(region))

def scale_l8(image):
    return (image
            .select(['SR_B2', 'SR_B3', 'SR_B4'])
            .multiply(0.0000275)
            .add(-0.2))

scol = col.map(scale_l8)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# # Problem
# When selecting the least cloudy image of the collection, it might not fully cover the region of interest (ROI).

# %%
# Least cloudy image
least_cloudy = scol.sort('CLOUD_COVER').first().clip(region)

m = geemap.Map(center=center_coords, zoom=13)
m.addLayer(
    least_cloudy,
    {'bands': ['SR_B4', 'SR_B3', 'SR_B2'], 'min': 0, 'max': 0.3},
    'Least Cloudy'
)
m.addLayerControl()
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[27.237, 14.65], controls=(WidgetControl(options=['position', 'transparent_bg'], position='topright…

# %% [markdown]
# # Compsing
# The image collection contains all swaths that intersect with the ROI and can be composed into a single image. This can be helpful to avoid invalid images, but leads to longer compute time as potentially many images need to be considered.
#
# ## Median
# Recuding the collection by taking the pixelwise median to cover the ROI makes it unlikely to include clouds and shadows as they have either very high or low pixel values. On the other hand, median compositions skew reality heavily as median pixel values are combined without further depedencies.

# %%
comp_median = scol.median().clip(region)

m = geemap.Map(center=center_coords, zoom=13)
m.addLayer(
    comp_median,
    {'bands': ['SR_B4', 'SR_B3', 'SR_B2'], 'min': 0, 'max': 0.3},
    'Median'
)
m.addLayerControl()
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[27.237, 14.65], controls=(WidgetControl(options=['position', 'transparent_bg'], position='topright…

# %% [markdown]
# ## Mosaic
# Patching images of the collection using `ee.ImageCollection.mosaic` solves this problem, as spatial gaps are filled by cohesive swaths.

# %%
comp_mosaic = scol.mosaic().clip(region)

m = geemap.Map(center=center_coords, zoom=13)
m.addLayer(
    comp_mosaic,
    {'bands': ['SR_B4', 'SR_B3', 'SR_B2'], 'min': 0, 'max': 0.3},
    'Mosaic'
)
m.addLayerControl()
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[27.237, 14.65], controls=(WidgetControl(options=['position', 'transparent_bg'], position='topright…

# %% [markdown]
# # Combination
# As compositions take more compute resources, the least cloudy image can be assest by its fraction of valid pixels. If it contains more than $1 \%$ of invalid pixels, a mosaic composition can be computed.

# %%
least_cloudy = scol.sort('CLOUD_COVER').first()

rgb_mask = (least_cloudy
            .select(['SR_B2', 'SR_B3', 'SR_B4'])
            .mask()
            .reduce(ee.Reducer.min()))

coverage_dict = rgb_mask.reduceRegion(
    reducer=ee.Reducer.mean(),
    geometry=region,
    scale=30,
    maxPixels=1e7
)

least_cloudy_coverage = ee.Number(coverage_dict.get('min'))
rgb_ok = least_cloudy_coverage.gte(0.99)

composite = scol.mosaic()
context = ee.Image(ee.Algorithms.If(rgb_ok, least_cloudy, composite))

m = geemap.Map(center=center_coords, zoom=13)
m.addLayer(
    context,
    {'bands': ['SR_B4', 'SR_B3', 'SR_B2'], 'min': 0, 'max': 0.3},
    'Combined Approach'
)
m.addLayerControl()
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[27.237, 14.65], controls=(WidgetControl(options=['position', 'transparent_bg'], position='topright…

# %% [markdown]
# # Swath intersections
# `ee.ImageCollection.mosaic` might produce chiseled transitions at the intersection of satellite swaths. Those intersections might fall into ROIs in the worst case, making `ee.ImageCollection.mosaic` as the best choice questionable.

# %%
comp_median = scol.median()
comp_mosaic = scol.mosaic()

m = geemap.Map(center=[27.28718614141461, 15.179246277997064], zoom=12)

m.addLayer(
    comp_mosaic,
    {'bands': ['SR_B4', 'SR_B3', 'SR_B2'], 'min': 0, 'max': 0.3},
    'Mosaic'
)

m.addLayer(
    comp_median,
    {'bands': ['SR_B4', 'SR_B3', 'SR_B2'], 'min': 0, 'max': 0.3},
    'Median'
)
m.addLayerControl()
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[27.28718614141461, 15.179246277997064], controls=(WidgetControl(options=['position', 'transparent_…

# %% [markdown]
# # Remainder
# However, the problem of cloudyness is not solved yet.

# %%
# Rectange surrounding the training sample 'airport 32' from fMoW
bbox = [-1.0140575646754744, -79.48694022837181, 
        -0.9691395896577617, -79.4420222533541]

center_coords = [-0.99, -79.46]
region = ee.Geometry.Rectangle(bbox)

col = (ee.ImageCollection('LANDSAT/LC08/C02/T1_L2')
       .filterBounds(region))

def scale_l8(image):
    return (image
            .select(['SR_B2', 'SR_B3', 'SR_B4'])
            .multiply(0.0000275)
            .add(-0.2))

scol = col.map(scale_l8)

least_cloudy = scol.sort('CLOUD_COVER').first()

rgb_mask = (least_cloudy
            .select(['SR_B2', 'SR_B3', 'SR_B4'])
            .mask()
            .reduce(ee.Reducer.min()))

coverage_dict = rgb_mask.reduceRegion(
    reducer=ee.Reducer.mean(),
    geometry=region,
    scale=30,
    maxPixels=1e7
)

least_cloudy_coverage = ee.Number(coverage_dict.get('min'))
rgb_ok = least_cloudy_coverage.gte(0.99)

composite = scol.mosaic()
context = ee.Image(ee.Algorithms.If(rgb_ok, least_cloudy, composite))

m = geemap.Map(center=center_coords, zoom=13)
m.addLayer(
    context,
    {'bands': ['SR_B4', 'SR_B3', 'SR_B2'], 'min': 0, 'max': 0.3},
    'Combined Approach'
)
m.addLayerControl()
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# File ~/.conda/envs/wilds/lib/python3.13/site-packages/ee/data.py:349, in _execute_cloud_call(call, num_retries)
#     348 try:
# --> 349   return call.execute(num_retries=num_retries)
#     350 except googleapiclient.errors.HttpError as e:
#
# File ~/.conda/envs/wilds/lib/python3.13/site-packages/googleapiclient/_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File ~/.conda/envs/wilds/lib/python3.13/site-packages/googleapiclient/http.py:938, in HttpRequest.execute(self, http, num_retries)
#     937 if resp.status >= 300:
# --> 938     raise HttpError(resp, content, uri=self.uri)
#     939 return self.postproc(resp, content)
#
# HttpError: <HttpError 400 when requesting https://earthengine.googleapis.com/v1/projects/seeing-the-big-picture/maps?fields=name&alt=json returned "Image.select: Parameter 'input' is required and may not be null.". Details: "Image.select: Parameter 'input' is required and may not be null.">
#
# During handling of the above exception, another exception occurred:
#
# EEException                               Traceback (most recent call last)
# Cell In[17], line 40
#      37 context = ee.Image(ee.Algorithms.If(rgb_ok, least_cloudy, composite))
#      39 m = geemap.Map(center=center_coords, zoom=13)
# ---> 40 m.addLayer(
#      41     context,
#      42     {'bands': ['SR_B4', 'SR_B3', 'SR_B2'], 'min': 0, 'max': 0.3},
#      43     'Combined Approach'
#      44 )
#      45 m.addLayerControl()
#      46 m
#
# File ~/.conda/envs/wilds/lib/python3.13/site-packages/geemap/geemap.py:437, in Map.add_ee_layer(self, ee_object, vis_params, name, shown, opacity)
#     432         if has_plot_dropdown:
#     433             self._plot_dropdown_widget.options = list(
#     434                 self.ee_raster_layers.keys()
#     435             )
# --> 437 super().add_layer(ee_object, vis_params, name, shown, opacity)
#     439 if isinstance(ee_object, (ee.Image, ee.ImageCollection)):
#     440     if has_plot_dropdown:
#
# File ~/.conda/envs/wilds/lib/python3.13/site-packages/geemap/core.py:1203, in Map.add_layer(self, ee_object, vis_params, name, shown, opacity)
#    1201 if isinstance(ee_object, ee.ImageCollection):
#    1202     ee_object = ee_object.mosaic()
# -> 1203 tile_layer = ee_tile_layers.EELeafletTileLayer(
#    1204     ee_object, vis_params, name, shown, opacity
#    1205 )
#    1207 # Remove the layer if it already exists.
#    1208 self.remove(name)
#
# File ~/.conda/envs/wilds/lib/python3.13/site-packages/geemap/ee_tile_layers.py:206, in EELeafletTileLayer.__init__(self, ee_object, vis_params, name, shown, opacity, **kwargs)
#     192 """Initialize the ipyleaflet tile layer.
#     193
#     194 Args:
#    (...)    203         number between 0 and 1. Defaults to 1.
#     204 """
#     205 self._ee_object = ee_object
# --> 206 self.url_format = _get_tile_url_format(
#     207     ee_object, _validate_vis_params(vis_params)
#     208 )
#     209 super().__init__(
#     210     url=self.url_format,
#     211     attribution="Google Earth Engine",
#    (...)    216     **kwargs,
#     217 )
#
# File ~/.conda/envs/wilds/lib/python3.13/site-packages/geemap/ee_tile_layers.py:36, in _get_tile_url_format(ee_object, vis_params)
#      25 """Gets the tile URL format for an EE object.
#      26
#      27 Args:
#    (...)     33     str: The tile URL format.
#      34 """
#      35 image = _ee_object_to_image(ee_object, vis_params)
# ---> 36 map_id_dict = ee.Image(image).getMapId(vis_params)
#      37 return map_id_dict["tile_fetcher"].url_format
#
# File ~/.conda/envs/wilds/lib/python3.13/site-packages/ee/image.py:154, in Image.getMapId(self, vis_params)
#     152 vis_image, request = self._apply_visualization(vis_params)
#     153 request['image'] = vis_image
# --> 154 response = data.getMapId(request)
#     155 response['image'] = self
#     156 return response
#
# File ~/.conda/envs/wilds/lib/python3.13/site-packages/ee/data.py:685, in getMapId(params)
#     680 queryParams = {
#     681     'fields': 'name',
#     682     'body': request,
#     683 }
#     684 _maybe_populate_workload_tag(queryParams)
# --> 685 result = _execute_cloud_call(
#     686     _get_cloud_projects()
#     687     .maps()
#     688     .create(parent=_get_projects_path(), **queryParams)
#     689 )
#     690 state = _get_state()
#     691 map_name = result['name']
#
# File ~/.conda/envs/wilds/lib/python3.13/site-packages/ee/data.py:351, in _execute_cloud_call(call, num_retries)
#     349   return call.execute(num_retries=num_retries)
#     350 except googleapiclient.errors.HttpError as e:
# --> 351   raise _translate_cloud_exception(e)
#
# EEException: Image.select: Parameter 'input' is required and may not be null.
